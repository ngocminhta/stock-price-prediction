# %% [markdown]
# **Outline:**
#
# 1. [Libraries and settings](#1-bullet)
# 2. [Nested CV](#2-bullet)

# %% [markdown]
# ## 1. [Libraries and settings](#1-bullet)

# %%
from DataPreprocessing import *
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3233 entries, 0 to 3232
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Open         3233 non-null   float64
#  1   High         3233 non-null   float64
#  2   Low          3233 non-null   float64
#  3   Close        3233 non-null   float64
#  4   Volume       3233 non-null   int64
#  5   TradingDate  3233 non-null   object
#  6   Code         3233 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 202.1+ KB

# %% [markdown]
# ## 2. [Nested CV - Day Forward Chaining](#2-bullet)

# %% [markdown]
# We try to use nested CV for time series to try to tune hyperparameters. After getting best hyperparameters, we retrain model and then evaluate

# %% [markdown]
# ### Create dataset

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]  
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 30
x_for_train, y_for_train = create_dataset(scaled_data, time_step)

x_for_train = x_for_train.reshape(x_for_train.shape[0],x_for_train.shape[1])
y_for_train = y_for_train.reshape(y_for_train.shape[0],1)

# %% [markdown]
# ### Day forward chaining

# %%
def performSVR(X_train, Y_train, X_test, Y_test, parameters):

    # Create and train the SVR model
    svr_model = SVR(C = parameters['C'], kernel = parameters['kernel'], gamma = parameters['gamma'])
    svr_model.fit(X_train, Y_train)

    # Make predictions on the test set
    Y_pred_train = svr_model.predict(X_train)
    Y_pred_test = svr_model.predict(X_test)

    # Calculate accuracy
    accuracy_train = r2_score(Y_train, Y_pred_train)
    accuracy_valid = r2_score(Y_test, Y_pred_test)
    
    mse_train = mean_squared_error(Y_train, Y_pred_train)
    mse_valid = mean_squared_error(Y_test, Y_pred_test)
    
    return [accuracy_train, accuracy_valid, mse_train, mse_valid]

# %%
from sklearn.model_selection import ParameterGrid

def performDayForwardChaining(X_train, y_train, number_folds):
    # Định nghĩa siêu tham số để tinh chỉnh
    param_grid = {
        'C': [0.01, 0.1, 1, 100],
        'kernel': ['linear', 'rbf', 'sigmoid'],
        'gamma' : [0.01, 0.001, 1]
    }

    # Chuyển đổi siêu tham số thành danh sách các tham số có thể
    param_list = list(ParameterGrid(param_grid))
    
    print('Size train set: ', X_train.shape)
    
    # k is the size of each fold. It is computed dividing the number of 
    # rows in X_train by number_folds. This number is floored and coerced to int
    k = int(np.floor(float(X_train.shape[0]) / number_folds))
    print('Size of each fold: ', k)
    
    results_valid = []
    results_test = []
    # loop from the first 2 folds to the total number of folds    
    for i in range(3, number_folds + 1):
        print('')
        
        split = float(i-1)/i
        
        print('Splitting the first ' + str(i) + ' chunks at ' + str(i-1) + '/' + str(i))

        X = X_train[:(k*i),:]
        y = y_train[:(k*i),:]
        print('Size of train + valid + test: ', X.shape) 

        index = int(np.floor(X.shape[0] * split))
        print(index)
        
        # folds used to train the model        
        X_train_validFolds = X[:index,:]        
        y_train_validFolds = y[:index,:]
        
        index_valid = int((i-2)*index/(i-1))
        
        X_trainFolds = X_train_validFolds[:index_valid,:]
        y_trainFolds = y_train_validFolds[:index_valid,:]
        
        X_validFolds = X_train_validFolds[index_valid:,:]
        y_validFolds = y_train_validFolds[index_valid:,:]
        
        # fold used to test the model
        X_testFolds = X[(index + 1):,:]
        y_testFolds = y[(index + 1):,:]
        
        for j,params in enumerate(param_list):
            print(f"Evaluating parameters {j+1}: {params}")
            accuracies_valid = performSVR(X_trainFolds, y_trainFolds, X_validFolds, y_validFolds, params)
            
            results_valid.append({
            'parameters': params,
            'accuracy_train': accuracies_valid[0],
            'accuracy_valid': accuracies_valid[1],
            'mse_train': accuracies_valid[2],
            'mse_valid': accuracies_valid[3]
            })

        for result in results_valid:
            print("Parameters: ", result['parameters'])
            print("Train Accuracy: ", result['accuracy_train'])
            print("Valid Accuracy: ", result['accuracy_valid'])
            print("Train MSE: ", result['mse_train'])
            print("Valid MSE: ", result['mse_valid'])
            print("------------------------")
        
        # Sắp xếp danh sách kết quả theo trường 'accuracy_valid' tăng dần
        sorted_results_valid = sorted(results_valid, key=lambda x: x['mse_valid'], reverse=False)

        # Lấy bộ tham số đầu tiên từ danh sách đã sắp xếp
        best_parameters = sorted_results_valid[0]['parameters']
        print(best_parameters)
        
        accuracies_test = performSVR(X_train_validFolds, y_train_validFolds, X_testFolds, y_testFolds, best_parameters)
        
        results_test.append({
            'parameters': best_parameters,
            'accuracy_train': accuracies_test[0],
            'accuracy_test': accuracies_test[1],
            'mse_train': accuracies_test[2],
            'mse_test': accuracies_test[3]
            })
        
    acc_train_model = 0
    acc_test_model = 0
    mse_train_model = 0
    mse_test_model = 0
    cnt = 0
    for result in results_test:
        acc_train_model += result['accuracy_train']
        acc_test_model += result['accuracy_test']
        mse_train_model += result['mse_train']
        mse_test_model += result['mse_test']
        cnt += 1

    acc_train_model = acc_train_model/cnt
    acc_test_model = acc_test_model/cnt
    mse_train_model = mse_train_model/cnt
    mse_test_model = mse_test_model/cnt
    # the function returns the mean of the accuracy on the n-1 folds    
    return acc_train_model, acc_test_model, mse_train_model, mse_test_model

# %%
accuracy_train_model, accuracy_test_model, mse_train_model, mse_test_model = performDayForwardChaining(x_for_train, y_for_train, number_folds=5)

print("Train Accuracy Model: ", accuracy_train_model)
print("Test Accuracy Model: ", accuracy_test_model)
print("Train MSE Model: ", mse_train_model)
print("Test MSE Model: ", mse_test_model)
print("------------------------")
# Out:
# Size train set:  (3202, 30)
# Size of each fold:  640
#
# Splitting the first 3 chunks at 2/3
# Size of train + valid + test:  (1920, 30)
# 1280
# Evaluating parameters 1: {'C': 0.01, 'gamma': 0.01, 'kernel': 'linear'}
# Evaluating parameters 2: {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# Evaluating parameters 3: {'C': 0.01, 'gamma': 0.01, 'kernel': 'sigmoid'}
# Evaluating parameters 4: {'C': 0.01, 'gamma': 0.001, 'kernel': 'linear'}
# Evaluating parameters 5: {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
# Evaluating parameters 6: {'C': 0.01, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Evaluating parameters 7: {'C': 0.01, 'gamma': 1, 'kernel': 'linear'}
# Evaluating parameters 8: {'C': 0.01, 'gamma': 1, 'kernel': 'rbf'}
# Evaluating parameters 9: {'C': 0.01, 'gamma': 1, 'kernel': 'sigmoid'}
# Evaluating parameters 10: {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
# Evaluating parameters 11: {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# Evaluating parameters 12: {'C': 0.1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# Evaluating parameters 13: {'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'}
# Evaluating parameters 14: {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# Evaluating parameters 15: {'C': 0.1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Evaluating parameters 16: {'C': 0.1, 'gamma': 1, 'kernel': 'linear'}
# Evaluating parameters 17: {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# Evaluating parameters 18: {'C': 0.1, 'gamma': 1, 'kernel': 'sigmoid'}
# Evaluating parameters 19: {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# Evaluating parameters 20: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# Evaluating parameters 21: {'C': 1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# Evaluating parameters 22: {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}
# Evaluating parameters 23: {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# Evaluating parameters 24: {'C': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Evaluating parameters 25: {'C': 1, 'gamma': 1, 'kernel': 'linear'}
# Evaluating parameters 26: {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# Evaluating parameters 27: {'C': 1, 'gamma': 1, 'kernel': 'sigmoid'}
# Evaluating parameters 28: {'C': 100, 'gamma': 0.01, 'kernel': 'linear'}
# Evaluating parameters 29: {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# Evaluating parameters 30: {'C': 100, 'gamma': 0.01, 'kernel': 'sigmoid'}
# Evaluating parameters 31: {'C': 100, 'gamma': 0.001, 'kernel': 'linear'}
# Evaluating parameters 32: {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# Evaluating parameters 33: {'C': 100, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Evaluating parameters 34: {'C': 100, 'gamma': 1, 'kernel': 'linear'}
# Evaluating parameters 35: {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# Evaluating parameters 36: {'C': 100, 'gamma': 1, 'kernel': 'sigmoid'}
# Parameters:  {'C': 0.01, 'gamma': 0.01, 'kernel': 'linear'}
# Train Accuracy:  0.9793404794779441
# Valid Accuracy:  0.9120429051036008
# Train MSE:  0.029173831927011774
# Valid MSE:  0.004150142059870339
# ------------------------
# Parameters:  {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# Train Accuracy:  0.3873058039203947
# Valid Accuracy:  -6.316593021015364
# Train MSE:  0.8652009846985182
# Valid MSE:  0.34522400344435106
# ------------------------
# Parameters:  {'C': 0.01, 'gamma': 0.01, 'kernel': 'sigmoid'}
# Train Accuracy:  -0.09749189898628985
# Valid Accuracy:  -0.6590199653279025
# Train MSE:  1.549796093675111
# Valid MSE:  0.07827871696287483
# ------------------------
# Parameters:  {'C': 0.01, 'gamma': 0.001, 'kernel': 'linear'}
# Train Accuracy:  0.9793404794779441
# Valid Accuracy:  0.9120429051036008
# Train MSE:  0.029173831927011774
# Valid MSE:  0.004150142059870339
# ------------------------
# Parameters:  {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
# Train Accuracy:  0.2506972249086876
# Valid Accuracy:  -11.765194491029096
# Train MSE:  1.0581094173807135
# Valid MSE:  0.6023092352247954
# ------------------------
# Parameters:  {'C': 0.01, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Train Accuracy:  0.14244792772311543
# Valid Accuracy:  -13.534048453949671
# Train MSE:  1.210970990278184
# Valid MSE:  0.6857703276805165
# ------------------------
# Parameters:  {'C': 0.01, 'gamma': 1, 'kernel': 'linear'}
# Train Accuracy:  0.9793404794779441
# Valid Accuracy:  0.9120429051036008
# Train MSE:  0.029173831927011774
# Valid MSE:  0.004150142059870339
# ------------------------
# Parameters:  {'C': 0.01, 'gamma': 1, 'kernel': 'rbf'}
# Train Accuracy:  0.051284047334035354
# Valid Accuracy:  -16.915264277541013
# Train MSE:  1.3397058135983024
# Valid MSE:  0.8453086346188463
# ------------------------
# Parameters:  {'C': 0.01, 'gamma': 1, 'kernel': 'sigmoid'}
# Train Accuracy:  -0.060665654082303844
# Valid Accuracy:  -25.014713173122622
# Train MSE:  1.49779282098614
# Valid MSE:  1.2274706826368702
# ------------------------
# Parameters:  {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
# Train Accuracy:  0.9889315182175631
# Valid Accuracy:  0.9469271485670288
# Train MSE:  0.015630083324696245
# Valid MSE:  0.002504174031994325
# ------------------------
# Parameters:  {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# Train Accuracy:  0.9052057103341573
# Valid Accuracy:  -2.1258818630334533
# Train MSE:  0.1338614161640069
# Valid MSE:  0.14749070338488482
# ------------------------
# Parameters:  {'C': 0.1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# Train Accuracy:  -5.372329640570534
# Valid Accuracy:  -157.35994649197323
# Train MSE:  8.998528001608246
# Valid MSE:  7.472009794198639
# ------------------------
# Parameters:  {'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'}
# Train Accuracy:  0.9889315182175631
# Valid Accuracy:  0.9469271485670288
# Train MSE:  0.015630083324696245
# Valid MSE:  0.002504174031994325
# ------------------------
# Parameters:  {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# Train Accuracy:  0.8077782866380037
# Valid Accuracy:  -0.9678638490936295
# Train MSE:  0.2714411475502657
# Valid MSE:  0.0928511172161979
# ------------------------
# Parameters:  {'C': 0.1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Train Accuracy:  0.705302559611532
# Valid Accuracy:  -0.9311934893655778
# Train MSE:  0.41614971586756744
# Valid MSE:  0.09112087359642831
# ------------------------
# Parameters:  {'C': 0.1, 'gamma': 1, 'kernel': 'linear'}
# Train Accuracy:  0.9889315182175631
# Valid Accuracy:  0.9469271485670288
# Train MSE:  0.015630083324696245
# Valid MSE:  0.002504174031994325
# ------------------------
# Parameters:  {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# Train Accuracy:  0.3451798756731803
# Valid Accuracy:  -30.61706389576881
# Train MSE:  0.9246880743984727
# Valid MSE:  1.4918103745694506
# ------------------------
# Parameters:  {'C': 0.1, 'gamma': 1, 'kernel': 'sigmoid'}
# Train Accuracy:  -0.061528181961871375
# Valid Accuracy:  -378.5537931739716
# Train MSE:  1.4990108184398563
# Valid MSE:  17.908756114444067
# ------------------------
# Parameters:  {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# Train Accuracy:  0.9898836141925434
# Valid Accuracy:  0.9399821103828774
# Train MSE:  0.014285604496022203
# Valid MSE:  0.0028318666997592334
# ------------------------
# Parameters:  {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# Train Accuracy:  0.9853052946826504
# Valid Accuracy:  -0.7590103698437003
# Train MSE:  0.020750765376556003
# Valid MSE:  0.08299663521441827
# ------------------------
# Parameters:  {'C': 1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# Train Accuracy:  -318.600243402878
# Valid Accuracy:  -19319.455922274392
# Train MSE:  451.31559442115076
# Valid MSE:  911.6107897077034
# ------------------------
# Parameters:  {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}
# Train Accuracy:  0.9898836141925434
# Valid Accuracy:  0.9399821103828774
# Train MSE:  0.014285604496022203
# Valid MSE:  0.0028318666997592334
# ------------------------
# Parameters:  {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# Train Accuracy:  0.956963116964013
# Valid Accuracy:  0.23460359700375522
# Train MSE:  0.06077347201809139
# Valid MSE:  0.03611424192999605
# ------------------------
# Parameters:  {'C': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Train Accuracy:  0.4443435021378894
# Valid Accuracy:  -1.8520928914853125
# Train MSE:  0.7846566071305909
# Valid MSE:  0.13457232394444357
# ------------------------
# Parameters:  {'C': 1, 'gamma': 1, 'kernel': 'linear'}
# Train Accuracy:  0.9898836141925434
# Valid Accuracy:  0.9399821103828774
# Train MSE:  0.014285604496022203
# Valid MSE:  0.0028318666997592334
# ------------------------
# Parameters:  {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# Train Accuracy:  0.8164257301443979
# Valid Accuracy:  -69.26346886749394
# Train MSE:  0.259229873663994
# Valid MSE:  3.315291140104654
# ------------------------
# Parameters:  {'C': 1, 'gamma': 1, 'kernel': 'sigmoid'}
# Train Accuracy:  -0.07120112372534293
# Valid Accuracy:  -32856.59892324443
# Train MSE:  1.5126702243755372
# Valid MSE:  1550.3434195765994
# ------------------------
# Parameters:  {'C': 100, 'gamma': 0.01, 'kernel': 'linear'}
# Train Accuracy:  0.9900043396847398
# Valid Accuracy:  0.9404514123810349
# Train MSE:  0.01411512497231395
# Valid MSE:  0.0028097232903659497
# ------------------------
# Parameters:  {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# Train Accuracy:  0.9955158950186023
# Valid Accuracy:  0.4657162502468829
# Train MSE:  0.006332118159795219
# Valid MSE:  0.02520948951721714
# ------------------------
# Parameters:  {'C': 100, 'gamma': 0.01, 'kernel': 'sigmoid'}
# Train Accuracy:  -2892940.1510332017
# Valid Accuracy:  -195500138.46822816
# Train MSE:  4085195.434466932
# Valid MSE:  9224421.889709612
# ------------------------
# Parameters:  {'C': 100, 'gamma': 0.001, 'kernel': 'linear'}
# Train Accuracy:  0.9900043396847398
# Valid Accuracy:  0.9404514123810349
# Train MSE:  0.01411512497231395
# Valid MSE:  0.0028097232903659497
# ------------------------
# Parameters:  {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# Train Accuracy:  0.9916560156067428
# Valid Accuracy:  0.9177414173741911
# Train MSE:  0.011782751590513264
# Valid MSE:  0.003881265109344402
# ------------------------
# Parameters:  {'C': 100, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Train Accuracy:  -7377.167594970672
# Valid Accuracy:  -25522.45336253393
# Train MSE:  10418.897239904529
# Valid MSE:  1204.2912221891431
# ------------------------
# Parameters:  {'C': 100, 'gamma': 1, 'kernel': 'linear'}
# Train Accuracy:  0.9900043396847398
# Valid Accuracy:  0.9404514123810349
# Train MSE:  0.01411512497231395
# Valid MSE:  0.0028097232903659497
# ------------------------
# Parameters:  {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# Train Accuracy:  0.9946059970065598
# Valid Accuracy:  -103.38694910397156
# Train MSE:  0.007617008176759088
# Valid MSE:  4.925363536485693
# ------------------------
# Parameters:  {'C': 100, 'gamma': 1, 'kernel': 'sigmoid'}
# Train Accuracy:  -11.89059905611999
# Valid Accuracy:  -345904758.99629974
# Train MSE:  18.203141253944146
# Valid MSE:  16321069.890505975
# ------------------------
# {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
# Splitting the first 4 chunks at 3/4
# Size of train + valid + test:  (2560, 30)
# 1920
# Evaluating parameters 1: {'C': 0.01, 'gamma': 0.01, 'kernel': 'linear'}
# Evaluating parameters 2: {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# Evaluating parameters 3: {'C': 0.01, 'gamma': 0.01, 'kernel': 'sigmoid'}
# Evaluating parameters 4: {'C': 0.01, 'gamma': 0.001, 'kernel': 'linear'}
# Evaluating parameters 5: {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
# Evaluating parameters 6: {'C': 0.01, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Evaluating parameters 7: {'C': 0.01, 'gamma': 1, 'kernel': 'linear'}
# Evaluating parameters 8: {'C': 0.01, 'gamma': 1, 'kernel': 'rbf'}
# Evaluating parameters 9: {'C': 0.01, 'gamma': 1, 'kernel': 'sigmoid'}
# Evaluating parameters 10: {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
# Evaluating parameters 11: {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# Evaluating parameters 12: {'C': 0.1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# Evaluating parameters 13: {'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'}
# Evaluating parameters 14: {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# Evaluating parameters 15: {'C': 0.1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Evaluating parameters 16: {'C': 0.1, 'gamma': 1, 'kernel': 'linear'}
# Evaluating parameters 17: {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# Evaluating parameters 18: {'C': 0.1, 'gamma': 1, 'kernel': 'sigmoid'}
# Evaluating parameters 19: {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# Evaluating parameters 20: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# Evaluating parameters 21: {'C': 1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# Evaluating parameters 22: {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}
# Evaluating parameters 23: {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# Evaluating parameters 24: {'C': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Evaluating parameters 25: {'C': 1, 'gamma': 1, 'kernel': 'linear'}
# Evaluating parameters 26: {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# Evaluating parameters 27: {'C': 1, 'gamma': 1, 'kernel': 'sigmoid'}
# Evaluating parameters 28: {'C': 100, 'gamma': 0.01, 'kernel': 'linear'}
# Evaluating parameters 29: {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# Evaluating parameters 30: {'C': 100, 'gamma': 0.01, 'kernel': 'sigmoid'}
# Evaluating parameters 31: {'C': 100, 'gamma': 0.001, 'kernel': 'linear'}
