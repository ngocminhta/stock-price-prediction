# %% [markdown]
# **Outline:**
#
# 1. [Libraries and settings](#1-bullet)
# 2. [Nested CV](#2-bullet)

# %% [markdown]
# ## 1. [Libraries and settings](#1-bullet)

# %%
from DataPreprocessing import *
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3320 entries, 0 to 3319
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Open         3320 non-null   float64
#  1   High         3320 non-null   float64
#  2   Low          3320 non-null   float64
#  3   Close        3320 non-null   float64
#  4   Volume       3204 non-null   float64
#  5   TradingDate  3320 non-null   object
#  6   Code         3320 non-null   object
# dtypes: float64(5), object(2)
# memory usage: 207.5+ KB

# %% [markdown]
# ## 2. [Nested CV - Day Forward Chaining](#2-bullet)

# %% [markdown]
# We try to use nested CV for time series to try to tune hyperparameters. After getting best hyperparameters, we retrain model and then evaluate

# %% [markdown]
# ### Create dataset

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]  
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 30
x_for_train, y_for_train = create_dataset(scaled_data, time_step)

x_for_train = x_for_train.reshape(x_for_train.shape[0],x_for_train.shape[1])
y_for_train = y_for_train.reshape(y_for_train.shape[0],1)

# %% [markdown]
# ### Day forward chaining

# %%
def performXGBoost(X_train, Y_train, X_test, Y_test, parameters):

    XGBoost_model = XGBRegressor(n_estimators = parameters['n_estimators'], max_depth = parameters['max_depth'], learning_rate = parameters['learning_rate'])
    XGBoost_model.fit(X_train, Y_train, verbose=False)

    # Make predictions on the test set
    Y_pred_train = XGBoost_model.predict(X_train)
    Y_pred_test = XGBoost_model.predict(X_test)

    # Calculate accuracy
    accuracy_train = XGBoost_model.score(X_train, Y_train)
    accuracy_valid = XGBoost_model.score(X_test, Y_test)
    
    mse_train = mean_squared_error(Y_train, Y_pred_train)
    mse_valid = mean_squared_error(Y_test, Y_pred_test)
    
    return [accuracy_train, accuracy_valid, mse_train, mse_valid]

# %%
from sklearn.model_selection import ParameterGrid

def performDayForwardChaining(X_train, y_train, number_folds):
    # Định nghĩa siêu tham số để tinh chỉnh
    param_grid = {
        'n_estimators': [100, 500, 1000],
        'max_depth': [3,6,10],
        'learning_rate' : [0.01, 0.05, 0.1]
    }

    # Chuyển đổi siêu tham số thành danh sách các tham số có thể
    param_list = list(ParameterGrid(param_grid))
    
    print('Size train set: ', X_train.shape)
    
    # k is the size of each fold. It is computed dividing the number of 
    # rows in X_train by number_folds. This number is floored and coerced to int
    k = int(np.floor(float(X_train.shape[0]) / number_folds))
    print('Size of each fold: ', k)
    
    results_valid = []
    results_test = []
    # loop from the first 2 folds to the total number of folds    
    for i in range(3, number_folds + 1):
        print('')
        
        split = float(i-1)/i
        
        print('Splitting the first ' + str(i) + ' chunks at ' + str(i-1) + '/' + str(i))

        X = X_train[:(k*i),:]
        y = y_train[:(k*i),:]
        print('Size of train + valid + test: ', X.shape) 

        index = int(np.floor(X.shape[0] * split))
        print(index)
        
        # folds used to train the model        
        X_train_validFolds = X[:index,:]        
        y_train_validFolds = y[:index,:]
        
        index_valid = int((i-2)*index/(i-1))
        
        X_trainFolds = X_train_validFolds[:index_valid,:]
        y_trainFolds = y_train_validFolds[:index_valid,:]
        
        X_validFolds = X_train_validFolds[index_valid:,:]
        y_validFolds = y_train_validFolds[index_valid:,:]
        
        # fold used to test the model
        X_testFolds = X[(index + 1):,:]
        y_testFolds = y[(index + 1):,:]
        
        for j,params in enumerate(param_list):
            print(f"Evaluating parameters {j+1}: {params}")
            accuracies_valid = performXGBoost(X_trainFolds, y_trainFolds, X_validFolds, y_validFolds, params)
            
            results_valid.append({
            'parameters': params,
            'accuracy_train': accuracies_valid[0],
            'accuracy_valid': accuracies_valid[1],
            'mse_train': accuracies_valid[2],
            'mse_valid': accuracies_valid[3]
            })

        for result in results_valid:
            print("Parameters: ", result['parameters'])
            print("Train Accuracy: ", result['accuracy_train'])
            print("Valid Accuracy: ", result['accuracy_valid'])
            print("Train MSE: ", result['mse_train'])
            print("Valid MSE: ", result['mse_valid'])
            print("------------------------")
        
        # Sắp xếp danh sách kết quả theo trường 'accuracy_valid' tăng dần
        sorted_results_valid = sorted(results_valid, key=lambda x: x['mse_valid'], reverse=False)

        # Lấy bộ tham số đầu tiên từ danh sách đã sắp xếp
        best_parameters = sorted_results_valid[0]['parameters']
        print(best_parameters)
        
        accuracies_test = performXGBoost(X_train_validFolds, y_train_validFolds, X_testFolds, y_testFolds, best_parameters)
        
        results_test.append({
            'parameters': best_parameters,
            'accuracy_train': accuracies_test[0],
            'accuracy_test': accuracies_test[1],
            'mse_train': accuracies_test[2],
            'mse_test': accuracies_test[3]
            })
        
    acc_train_model = 0
    acc_test_model = 0
    mse_train_model = 0
    mse_test_model = 0
    cnt = 0
    for result in results_test:
        acc_train_model += result['accuracy_train']
        acc_test_model += result['accuracy_test']
        mse_train_model += result['mse_train']
        mse_test_model += result['mse_test']
        cnt += 1

    acc_train_model = acc_train_model/cnt
    acc_test_model = acc_test_model/cnt
    mse_train_model = mse_train_model/cnt
    mse_test_model = mse_test_model/cnt
    # the function returns the mean of the accuracy on the n-1 folds    
    return acc_train_model, acc_test_model, mse_train_model, mse_test_model

# %%
accuracy_train_model, accuracy_test_model, mse_train_model, mse_test_model = performDayForwardChaining(x_for_train, y_for_train, number_folds=5)

print("Train Accuracy Model: ", accuracy_train_model)
print("Test Accuracy Model: ", accuracy_test_model)
print("Train MSE Model: ", mse_train_model)
print("Test MSE Model: ", mse_test_model)
print("------------------------")
# Out:
# Size train set:  (3173, 30)
# Size of each fold:  634
#
# Splitting the first 3 chunks at 2/3
# Size of train + valid + test:  (1902, 30)
# 1268
# Evaluating parameters 1: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}
# Evaluating parameters 2: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# Evaluating parameters 3: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000}
# Evaluating parameters 4: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 100}
# Evaluating parameters 5: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 500}
# Evaluating parameters 6: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# Evaluating parameters 7: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# Evaluating parameters 8: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 500}
# Evaluating parameters 9: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 1000}
# Evaluating parameters 10: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Evaluating parameters 11: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}
# Evaluating parameters 12: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 1000}
# Evaluating parameters 13: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100}
# Evaluating parameters 14: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 500}
# Evaluating parameters 15: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 1000}
# Evaluating parameters 16: {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 100}
# Evaluating parameters 17: {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 500}
# Evaluating parameters 18: {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 1000}
# Evaluating parameters 19: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Evaluating parameters 20: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# Evaluating parameters 21: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000}
# Evaluating parameters 22: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}
# Evaluating parameters 23: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 500}
# Evaluating parameters 24: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 1000}
# Evaluating parameters 25: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100}
# Evaluating parameters 26: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500}
# Evaluating parameters 27: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 1000}
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  -7.751154670539007
# Valid Accuracy:  -0.7100716974317491
# Train MSE:  0.33594961140557844
# Valid MSE:  0.27776843925176453
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9817016524300898
# Valid Accuracy:  0.7925941572851807
# Train MSE:  0.0007024584739852307
# Valid MSE:  0.033689112163609515
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.9891873839762775
# Valid Accuracy:  0.7624766956904807
# Train MSE:  0.0004150874128274968
# Valid MSE:  0.038581117752584916
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  -7.751154670539007
# Valid Accuracy:  -0.7100716974317491
# Train MSE:  0.33594961140557844
# Valid MSE:  0.27776843925176453
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9883063150266875
# Valid Accuracy:  0.8085017855803913
# Train MSE:  0.0004489109232532422
# Valid MSE:  0.0311052222071861
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.9972286164164378
# Valid Accuracy:  0.7637050375564057
# Train MSE:  0.00010639113042852709
# Valid MSE:  0.03838159711056857
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  -7.751154670539007
# Valid Accuracy:  -0.7100716974317491
# Train MSE:  0.33594961140557844
# Valid MSE:  0.27776843925176453
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9923330039266793
# Valid Accuracy:  0.8089471230965263
# Train MSE:  0.0002943296568796127
# Valid MSE:  0.03103288564551862
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.9996463935601353
# Valid Accuracy:  0.7672415108592234
# Train MSE:  1.3574659634686282e-05
# Valid MSE:  0.03780716466352293
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  0.9825065475926618
# Valid Accuracy:  0.7983311171143617
# Train MSE:  0.0006715592124285104
# Valid MSE:  0.03275725276836024
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9958208290474303
# Valid Accuracy:  0.7591244487875256
# Train MSE:  0.00016043492663200546
# Valid MSE:  0.03912562614461249
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.9988532888971734
# Valid Accuracy:  0.7616998921819463
# Train MSE:  4.402129363407969e-05
# Valid MSE:  0.038707294624873344
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  0.9889381684742454
# Valid Accuracy:  0.7955362495341483
# Train MSE:  0.00042465459044187443
# Valid MSE:  0.03321122555022497
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9998367326377677
# Valid Accuracy:  0.7457636478887131
# Train MSE:  6.267699402203664e-06
# Valid MSE:  0.041295832702846494
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.999932981653278
# Valid Accuracy:  0.7454863996682304
# Train MSE:  2.572779065839202e-06
# Valid MSE:  0.0413408663734256
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  0.9929415465868834
# Valid Accuracy:  0.8023701617930786
# Train MSE:  0.0002709682059721655
# Valid MSE:  0.0321011872138222
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9999642742816661
# Valid Accuracy:  0.7593576738165261
# Train MSE:  1.3714808666151212e-06
# Valid MSE:  0.039087743199472114
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.9999642742816661
# Valid Accuracy:  0.7593576738165261
# Train MSE:  1.3714808666151212e-06
# Valid MSE:  0.039087743199472114
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  0.9893423981922566
# Valid Accuracy:  0.7441716745057276
# Train MSE:  0.000409136544904224
# Valid MSE:  0.04155441832974524
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9989488959940682
# Valid Accuracy:  0.7521360738631991
# Train MSE:  4.035101602402171e-05
# Valid MSE:  0.040260753986650695
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.9998910599943527
# Valid Accuracy:  0.7465738430601567
# Train MSE:  4.182116982454578e-06
# Valid MSE:  0.04116423199359015
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  0.9974485914949935
# Valid Accuracy:  0.7537913247673992
# Train MSE:  9.79464685591047e-05
# Valid MSE:  0.0399918901367196
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9999341483843003
# Valid Accuracy:  0.7467970167550209
# Train MSE:  2.5279892240084026e-06
# Valid MSE:  0.041127981695431554
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.9999341483843003
# Valid Accuracy:  0.7467970167550209
# Train MSE:  2.5279892240084026e-06
# Valid MSE:  0.041127981695431554
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  0.9997096065345679
# Valid Accuracy:  0.7567839292891995
# Train MSE:  1.1147965673042415e-05
# Valid MSE:  0.039505798770745504
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9999659538877744
# Valid Accuracy:  0.7532961287022845
# Train MSE:  1.3070021731606223e-06
# Valid MSE:  0.04007232526604026
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.9999659538877744
# Valid Accuracy:  0.7532961287022845
# Train MSE:  1.3070021731606223e-06
# Valid MSE:  0.04007232526604026
# ------------------------
# {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 500}
# Splitting the first 4 chunks at 3/4
# Size of train + valid + test:  (2536, 30)
# 1902
# Evaluating parameters 1: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}
# Evaluating parameters 2: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# Evaluating parameters 3: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000}
# Evaluating parameters 4: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 100}
# Evaluating parameters 5: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 500}
# Evaluating parameters 6: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# Evaluating parameters 7: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# Evaluating parameters 8: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 500}
# Evaluating parameters 9: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 1000}
# Evaluating parameters 10: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Evaluating parameters 11: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}
# Evaluating parameters 12: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 1000}
# Evaluating parameters 13: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100}
# Evaluating parameters 14: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 500}
# Evaluating parameters 15: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 1000}
# Evaluating parameters 16: {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 100}
# Evaluating parameters 17: {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 500}
# Evaluating parameters 18: {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 1000}
# Evaluating parameters 19: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Evaluating parameters 20: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# Evaluating parameters 21: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000}
# Evaluating parameters 22: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}
# Evaluating parameters 23: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 500}
# Evaluating parameters 24: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 1000}
# Evaluating parameters 25: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100}
# Evaluating parameters 26: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500}
# Evaluating parameters 27: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 1000}
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  -7.751154670539007
# Valid Accuracy:  -0.7100716974317491
# Train MSE:  0.33594961140557844
# Valid MSE:  0.27776843925176453
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9817016524300898
# Valid Accuracy:  0.7925941572851807
# Train MSE:  0.0007024584739852307
# Valid MSE:  0.033689112163609515
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.9891873839762775
# Valid Accuracy:  0.7624766956904807
# Train MSE:  0.0004150874128274968
# Valid MSE:  0.038581117752584916
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  -7.751154670539007
# Valid Accuracy:  -0.7100716974317491
# Train MSE:  0.33594961140557844
# Valid MSE:  0.27776843925176453
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9883063150266875
# Valid Accuracy:  0.8085017855803913
# Train MSE:  0.0004489109232532422
# Valid MSE:  0.0311052222071861
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.9972286164164378
# Valid Accuracy:  0.7637050375564057
# Train MSE:  0.00010639113042852709
# Valid MSE:  0.03838159711056857
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  -7.751154670539007
# Valid Accuracy:  -0.7100716974317491
# Train MSE:  0.33594961140557844
# Valid MSE:  0.27776843925176453
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9923330039266793
# Valid Accuracy:  0.8089471230965263
# Train MSE:  0.0002943296568796127
# Valid MSE:  0.03103288564551862
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.9996463935601353
# Valid Accuracy:  0.7672415108592234
# Train MSE:  1.3574659634686282e-05
# Valid MSE:  0.03780716466352293
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  0.9825065475926618
# Valid Accuracy:  0.7983311171143617
# Train MSE:  0.0006715592124285104
# Valid MSE:  0.03275725276836024
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9958208290474303
# Valid Accuracy:  0.7591244487875256
# Train MSE:  0.00016043492663200546
# Valid MSE:  0.03912562614461249
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.9988532888971734
# Valid Accuracy:  0.7616998921819463
# Train MSE:  4.402129363407969e-05
# Valid MSE:  0.038707294624873344
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  0.9889381684742454
# Valid Accuracy:  0.7955362495341483
# Train MSE:  0.00042465459044187443
# Valid MSE:  0.03321122555022497
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9998367326377677
# Valid Accuracy:  0.7457636478887131
# Train MSE:  6.267699402203664e-06
# Valid MSE:  0.041295832702846494
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.999932981653278
# Valid Accuracy:  0.7454863996682304
# Train MSE:  2.572779065839202e-06
# Valid MSE:  0.0413408663734256
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  0.9929415465868834
# Valid Accuracy:  0.8023701617930786
# Train MSE:  0.0002709682059721655
# Valid MSE:  0.0321011872138222
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9999642742816661
# Valid Accuracy:  0.7593576738165261
# Train MSE:  1.3714808666151212e-06
# Valid MSE:  0.039087743199472114
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.9999642742816661
# Valid Accuracy:  0.7593576738165261
# Train MSE:  1.3714808666151212e-06
# Valid MSE:  0.039087743199472114
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  0.9893423981922566
# Valid Accuracy:  0.7441716745057276
# Train MSE:  0.000409136544904224
# Valid MSE:  0.04155441832974524
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9989488959940682
# Valid Accuracy:  0.7521360738631991
# Train MSE:  4.035101602402171e-05
# Valid MSE:  0.040260753986650695
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.9998910599943527
# Valid Accuracy:  0.7465738430601567
# Train MSE:  4.182116982454578e-06
# Valid MSE:  0.04116423199359015
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  0.9974485914949935
# Valid Accuracy:  0.7537913247673992
# Train MSE:  9.79464685591047e-05
# Valid MSE:  0.0399918901367196
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9999341483843003
# Valid Accuracy:  0.7467970167550209
# Train MSE:  2.5279892240084026e-06
# Valid MSE:  0.041127981695431554
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.9999341483843003
# Valid Accuracy:  0.7467970167550209
# Train MSE:  2.5279892240084026e-06
# Valid MSE:  0.041127981695431554
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  0.9997096065345679
# Valid Accuracy:  0.7567839292891995
# Train MSE:  1.1147965673042415e-05
# Valid MSE:  0.039505798770745504
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9999659538877744
# Valid Accuracy:  0.7532961287022845
# Train MSE:  1.3070021731606223e-06
# Valid MSE:  0.04007232526604026
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.9999659538877744
# Valid Accuracy:  0.7532961287022845
# Train MSE:  1.3070021731606223e-06
# Valid MSE:  0.04007232526604026
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  -1.8758628779872368
# Valid Accuracy:  -0.7718432060673
# Train MSE:  0.30914900688359476
# Valid MSE:  0.6760114830453905
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9941338321948091
# Valid Accuracy:  -1.35080276681171
# Train MSE:  0.0006306002852460503
# Valid MSE:  0.8969019715163385
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.995932387849981
# Valid Accuracy:  -1.3124263735374098
# Train MSE:  0.00043725946260905925
# Valid MSE:  0.8822602230577519
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  -1.8758482393859683
# Valid Accuracy:  -0.742313521546381
# Train MSE:  0.3091474332657846
# Valid MSE:  0.6647450200996332
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9961970458941503
# Valid Accuracy:  -1.1784335538394837
# Train MSE:  0.00040880929826187814
# Valid MSE:  0.831137931620646
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.998618617168835
# Valid Accuracy:  -1.1952367340131569
# Train MSE:  0.00014849565104424115
# Valid MSE:  0.8375488503239414
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  -1.8758482393859683
# Valid Accuracy:  -0.742313521546381
# Train MSE:  0.3091474332657846
# Valid MSE:  0.6647450200996332
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9974524812903217
# Valid Accuracy:  -1.1426609655642626
# Train MSE:  0.0002738527226533192
# Valid MSE:  0.8174896130959053
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.9997289956219012
# Valid Accuracy:  -1.1611572331329878
# Train MSE:  2.9132381446841973e-05
# Valid MSE:  0.8245464955712406
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  0.9943540892474552
# Valid Accuracy:  -1.3618694536144211
# Train MSE:  0.000606923130954083
# Valid MSE:  0.901124245435544
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9978494246122911
# Valid Accuracy:  -1.2915511749662674
# Train MSE:  0.00023118217854803207
# Valid MSE:  0.8742957068428737
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.999038782018811
# Valid Accuracy:  -1.2791446987372868
# Train MSE:  0.00010332884316487631
# Valid MSE:  0.8695622629544972
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  0.9964015553991296
# Valid Accuracy:  -1.1898613759375793
# Train MSE:  0.00038682497110686953
# Valid MSE:  0.8354979895185791
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9997941462049302
# Valid Accuracy:  -1.1919177828564198
# Train MSE:  2.2128835417067927e-05
# Valid MSE:  0.8362825706181874
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.9999708351565239
# Valid Accuracy:  -1.1909341559832263
# Train MSE:  3.1351572655185607e-06
# Valid MSE:  0.8359072873769652
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  0.99766480851043
# Valid Accuracy:  -1.1364670359560418
# Train MSE:  0.0002510280081186773
# Valid MSE:  0.8151264426268741
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9999831368939559
# Valid Accuracy:  -1.1530578672934122
# Train MSE:  1.8127472371528394e-06
# Valid MSE:  0.8214563438613208
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.999983136530654
# Valid Accuracy:  -1.1530764600589043
# Train MSE:  1.8127862913288215e-06
# Valid MSE:  0.8214634375606568
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  0.996003086022261
# Valid Accuracy:  -1.3202185451627937
# Train MSE:  0.0004296595627959795
# Valid MSE:  0.8852331709340552
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9990835012227552
# Valid Accuracy:  -1.2786028141632184
# Train MSE:  9.852162596623355e-05
# Valid MSE:  0.8693555176887192
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.999786017148603
# Valid Accuracy:  -1.2628820512252243
# Train MSE:  2.300269129861142e-05
# Valid MSE:  0.8633575737217096
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  0.9987641733576806
# Valid Accuracy:  -1.1780473736491186
# Train MSE:  0.00013284867720144078
# Valid MSE:  0.8309905922610925
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9999741884188794
# Valid Accuracy:  -1.165215870522215
# Train MSE:  2.774688852723744e-06
# Valid MSE:  0.8260949878256567
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.9999741879803979
# Valid Accuracy:  -1.1652264045096556
# Train MSE:  2.7747359885362193e-06
# Valid MSE:  0.8260990068587448
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  0.999775829254312
# Valid Accuracy:  -1.1589139008996927
# Train MSE:  2.409786778510155e-05
# Valid MSE:  0.8236905968411496
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9999842037898045
# Valid Accuracy:  -1.157113438699445
# Train MSE:  1.698058253001787e-06
# Valid MSE:  0.8230036663509185
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.999984203643354
# Valid Accuracy:  -1.1571202966359508
# Train MSE:  1.6980739961085646e-06
# Valid MSE:  0.8230062828599933
# ------------------------
# {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 500}
# Splitting the first 5 chunks at 4/5
# Size of train + valid + test:  (3170, 30)
# 2536
# Evaluating parameters 1: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}
# Evaluating parameters 2: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# Evaluating parameters 3: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000}
# Evaluating parameters 4: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 100}
# Evaluating parameters 5: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 500}
# Evaluating parameters 6: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# Evaluating parameters 7: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# Evaluating parameters 8: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 500}
# Evaluating parameters 9: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 1000}
# Evaluating parameters 10: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Evaluating parameters 11: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}
# Evaluating parameters 12: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 1000}
# Evaluating parameters 13: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100}
# Evaluating parameters 14: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 500}
# Evaluating parameters 15: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 1000}
# Evaluating parameters 16: {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 100}
# Evaluating parameters 17: {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 500}
# Evaluating parameters 18: {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 1000}
# Evaluating parameters 19: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Evaluating parameters 20: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# Evaluating parameters 21: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000}
# Evaluating parameters 22: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}
# Evaluating parameters 23: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 500}
# Evaluating parameters 24: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 1000}
# Evaluating parameters 25: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100}
# Evaluating parameters 26: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500}
# Evaluating parameters 27: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 1000}
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  -7.751154670539007
# Valid Accuracy:  -0.7100716974317491
# Train MSE:  0.33594961140557844
# Valid MSE:  0.27776843925176453
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9817016524300898
# Valid Accuracy:  0.7925941572851807
# Train MSE:  0.0007024584739852307
# Valid MSE:  0.033689112163609515
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.9891873839762775
# Valid Accuracy:  0.7624766956904807
# Train MSE:  0.0004150874128274968
# Valid MSE:  0.038581117752584916
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  -7.751154670539007
# Valid Accuracy:  -0.7100716974317491
# Train MSE:  0.33594961140557844
# Valid MSE:  0.27776843925176453
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9883063150266875
# Valid Accuracy:  0.8085017855803913
# Train MSE:  0.0004489109232532422
# Valid MSE:  0.0311052222071861
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.9972286164164378
# Valid Accuracy:  0.7637050375564057
# Train MSE:  0.00010639113042852709
# Valid MSE:  0.03838159711056857
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  -7.751154670539007
# Valid Accuracy:  -0.7100716974317491
# Train MSE:  0.33594961140557844
# Valid MSE:  0.27776843925176453
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9923330039266793
# Valid Accuracy:  0.8089471230965263
# Train MSE:  0.0002943296568796127
# Valid MSE:  0.03103288564551862
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.9996463935601353
# Valid Accuracy:  0.7672415108592234
# Train MSE:  1.3574659634686282e-05
# Valid MSE:  0.03780716466352293
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  0.9825065475926618
# Valid Accuracy:  0.7983311171143617
# Train MSE:  0.0006715592124285104
# Valid MSE:  0.03275725276836024
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9958208290474303
# Valid Accuracy:  0.7591244487875256
# Train MSE:  0.00016043492663200546
# Valid MSE:  0.03912562614461249
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.9988532888971734
# Valid Accuracy:  0.7616998921819463
# Train MSE:  4.402129363407969e-05
# Valid MSE:  0.038707294624873344
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  0.9889381684742454
# Valid Accuracy:  0.7955362495341483
# Train MSE:  0.00042465459044187443
# Valid MSE:  0.03321122555022497
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9998367326377677
# Valid Accuracy:  0.7457636478887131
# Train MSE:  6.267699402203664e-06
# Valid MSE:  0.041295832702846494
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.999932981653278
# Valid Accuracy:  0.7454863996682304
# Train MSE:  2.572779065839202e-06
# Valid MSE:  0.0413408663734256
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  0.9929415465868834
# Valid Accuracy:  0.8023701617930786
# Train MSE:  0.0002709682059721655
# Valid MSE:  0.0321011872138222
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9999642742816661
# Valid Accuracy:  0.7593576738165261
# Train MSE:  1.3714808666151212e-06
# Valid MSE:  0.039087743199472114
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.9999642742816661
# Valid Accuracy:  0.7593576738165261
# Train MSE:  1.3714808666151212e-06
# Valid MSE:  0.039087743199472114
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  0.9893423981922566
# Valid Accuracy:  0.7441716745057276
# Train MSE:  0.000409136544904224
# Valid MSE:  0.04155441832974524
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9989488959940682
# Valid Accuracy:  0.7521360738631991
# Train MSE:  4.035101602402171e-05
# Valid MSE:  0.040260753986650695
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.9998910599943527
# Valid Accuracy:  0.7465738430601567
# Train MSE:  4.182116982454578e-06
# Valid MSE:  0.04116423199359015
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  0.9974485914949935
# Valid Accuracy:  0.7537913247673992
# Train MSE:  9.79464685591047e-05
# Valid MSE:  0.0399918901367196
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9999341483843003
# Valid Accuracy:  0.7467970167550209
# Train MSE:  2.5279892240084026e-06
# Valid MSE:  0.041127981695431554
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.9999341483843003
# Valid Accuracy:  0.7467970167550209
# Train MSE:  2.5279892240084026e-06
# Valid MSE:  0.041127981695431554
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  0.9997096065345679
# Valid Accuracy:  0.7567839292891995
# Train MSE:  1.1147965673042415e-05
# Valid MSE:  0.039505798770745504
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9999659538877744
# Valid Accuracy:  0.7532961287022845
# Train MSE:  1.3070021731606223e-06
# Valid MSE:  0.04007232526604026
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.9999659538877744
# Valid Accuracy:  0.7532961287022845
# Train MSE:  1.3070021731606223e-06
# Valid MSE:  0.04007232526604026
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  -1.8758628779872368
# Valid Accuracy:  -0.7718432060673
# Train MSE:  0.30914900688359476
# Valid MSE:  0.6760114830453905
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9941338321948091
# Valid Accuracy:  -1.35080276681171
# Train MSE:  0.0006306002852460503
# Valid MSE:  0.8969019715163385
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.995932387849981
# Valid Accuracy:  -1.3124263735374098
# Train MSE:  0.00043725946260905925
# Valid MSE:  0.8822602230577519
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  -1.8758482393859683
# Valid Accuracy:  -0.742313521546381
# Train MSE:  0.3091474332657846
# Valid MSE:  0.6647450200996332
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9961970458941503
# Valid Accuracy:  -1.1784335538394837
# Train MSE:  0.00040880929826187814
# Valid MSE:  0.831137931620646
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.998618617168835
# Valid Accuracy:  -1.1952367340131569
# Train MSE:  0.00014849565104424115
# Valid MSE:  0.8375488503239414
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  -1.8758482393859683
# Valid Accuracy:  -0.742313521546381
# Train MSE:  0.3091474332657846
# Valid MSE:  0.6647450200996332
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9974524812903217
# Valid Accuracy:  -1.1426609655642626
# Train MSE:  0.0002738527226533192
# Valid MSE:  0.8174896130959053
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.9997289956219012
# Valid Accuracy:  -1.1611572331329878
# Train MSE:  2.9132381446841973e-05
# Valid MSE:  0.8245464955712406
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  0.9943540892474552
# Valid Accuracy:  -1.3618694536144211
# Train MSE:  0.000606923130954083
# Valid MSE:  0.901124245435544
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9978494246122911
# Valid Accuracy:  -1.2915511749662674
# Train MSE:  0.00023118217854803207
# Valid MSE:  0.8742957068428737
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.999038782018811
# Valid Accuracy:  -1.2791446987372868
# Train MSE:  0.00010332884316487631
# Valid MSE:  0.8695622629544972
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  0.9964015553991296
# Valid Accuracy:  -1.1898613759375793
# Train MSE:  0.00038682497110686953
# Valid MSE:  0.8354979895185791
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9997941462049302
# Valid Accuracy:  -1.1919177828564198
# Train MSE:  2.2128835417067927e-05
# Valid MSE:  0.8362825706181874
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.9999708351565239
# Valid Accuracy:  -1.1909341559832263
# Train MSE:  3.1351572655185607e-06
# Valid MSE:  0.8359072873769652
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  0.99766480851043
# Valid Accuracy:  -1.1364670359560418
# Train MSE:  0.0002510280081186773
# Valid MSE:  0.8151264426268741
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9999831368939559
# Valid Accuracy:  -1.1530578672934122
# Train MSE:  1.8127472371528394e-06
# Valid MSE:  0.8214563438613208
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.999983136530654
# Valid Accuracy:  -1.1530764600589043
# Train MSE:  1.8127862913288215e-06
# Valid MSE:  0.8214634375606568
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  0.996003086022261
# Valid Accuracy:  -1.3202185451627937
# Train MSE:  0.0004296595627959795
# Valid MSE:  0.8852331709340552
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9990835012227552
# Valid Accuracy:  -1.2786028141632184
# Train MSE:  9.852162596623355e-05
# Valid MSE:  0.8693555176887192
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.999786017148603
# Valid Accuracy:  -1.2628820512252243
# Train MSE:  2.300269129861142e-05
# Valid MSE:  0.8633575737217096
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  0.9987641733576806
# Valid Accuracy:  -1.1780473736491186
# Train MSE:  0.00013284867720144078
# Valid MSE:  0.8309905922610925
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9999741884188794
# Valid Accuracy:  -1.165215870522215
# Train MSE:  2.774688852723744e-06
# Valid MSE:  0.8260949878256567
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.9999741879803979
# Valid Accuracy:  -1.1652264045096556
# Train MSE:  2.7747359885362193e-06
# Valid MSE:  0.8260990068587448
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  0.999775829254312
# Valid Accuracy:  -1.1589139008996927
# Train MSE:  2.409786778510155e-05
# Valid MSE:  0.8236905968411496
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9999842037898045
# Valid Accuracy:  -1.157113438699445
# Train MSE:  1.698058253001787e-06
# Valid MSE:  0.8230036663509185
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.999984203643354
# Valid Accuracy:  -1.1571202966359508
# Train MSE:  1.6980739961085646e-06
# Valid MSE:  0.8230062828599933
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  0.7226273834721124
# Valid Accuracy:  -0.8679918196270122
# Train MSE:  0.22865725295394998
# Valid MSE:  0.03672701667428176
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9986090110105381
# Valid Accuracy:  0.9332656344896751
# Train MSE:  0.0011466875324643128
# Valid MSE:  0.0013120797045753144
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.9989748240402522
# Valid Accuracy:  0.9342978940140337
# Train MSE:  0.0008451227871183642
# Valid MSE:  0.0012917842127187847
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  0.7252116562108308
# Valid Accuracy:  -0.9226777731320623
# Train MSE:  0.22652685986498503
# Valid MSE:  0.03780220978012201
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9994128551399846
# Valid Accuracy:  0.9158716322013727
# Train MSE:  0.0004840237383839662
# Valid MSE:  0.0016540671829800837
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.9997262950970279
# Valid Accuracy:  0.9173614812202258
# Train MSE:  0.00022563370536375543
# Valid MSE:  0.001624774918858442
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  0.7252399643446834
# Valid Accuracy:  -0.9235314512297537
# Train MSE:  0.22650352353062012
# Valid MSE:  0.03781899414148749
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9997138923243669
# Valid Accuracy:  0.9117009525845102
# Train MSE:  0.0002358581606872944
# Valid MSE:  0.0017360678738943412
# ------------------------
# Parameters:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.9999618170758429
# Valid Accuracy:  0.9127483864575816
# Train MSE:  3.147680061867472e-05
# Valid MSE:  0.00171547403567872
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  0.9986349657031561
# Valid Accuracy:  0.9315703820843209
# Train MSE:  0.0011252913009632834
# Valid MSE:  0.0013454104519074915
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9993651742426178
# Valid Accuracy:  0.9309356819673399
# Train MSE:  0.0005233303691059467
# Valid MSE:  0.001357889436844473
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.9996678525453303
# Valid Accuracy:  0.9273032000624047
# Train MSE:  0.0002738119051228843
# Valid MSE:  0.0014293084987963699
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  0.9994418274825714
# Valid Accuracy:  0.9172112720739454
# Train MSE:  0.0004601398512487208
# Valid MSE:  0.0016277282154211494
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9999281383206458
# Valid Accuracy:  0.9166460778811304
# Train MSE:  5.924050614470674e-05
# Valid MSE:  0.001638840628401561
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.9999902460123218
# Valid Accuracy:  0.9148924823164277
# Train MSE:  8.040880371578028e-06
# Valid MSE:  0.0016733184740045676
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  0.9997357614935561
# Valid Accuracy:  0.9114956769671463
# Train MSE:  0.00021782990608245568
# Valid MSE:  0.0017401038450064927
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9999968863505526
# Valid Accuracy:  0.9110309742872913
# Train MSE:  2.566794581980364e-06
# Valid MSE:  0.0017492404712445152
# ------------------------
# Parameters:  {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.9999968862732356
# Valid Accuracy:  0.9110303124429985
# Train MSE:  2.566858319720099e-06
# Valid MSE:  0.0017492534839173338
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Train Accuracy:  0.9989660170167565
# Valid Accuracy:  0.9321443252702153
# Train MSE:  0.0008523830200297206
# Valid MSE:  0.0013341260229624858
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# Train Accuracy:  0.9996758800375114
# Valid Accuracy:  0.9239164495365295
# Train MSE:  0.00026719429328646955
# Valid MSE:  0.0014958961796033938
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy:  0.9998913751673832
# Valid Accuracy:  0.9189064119609287
# Train MSE:  8.954689233439591e-05
# Valid MSE:  0.0015943996803385355
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}
# Train Accuracy:  0.99971604905584
# Valid Accuracy:  0.9225830166789538
# Train MSE:  0.00023408021915812888
# Valid MSE:  0.0015221131096132886
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 500}
# Train Accuracy:  0.9999901990895572
# Valid Accuracy:  0.9167995183931845
# Train MSE:  8.07956202147372e-06
# Valid MSE:  0.0016358237992133856
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 1000}
# Train Accuracy:  0.9999954793250049
# Valid Accuracy:  0.9165095221841677
# Train MSE:  3.72670214829361e-06
# Valid MSE:  0.0016415254813578846
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100}
# Train Accuracy:  0.99996561141505
# Valid Accuracy:  0.9029922344646245
# Train MSE:  2.8348866827823984e-05
# Valid MSE:  0.0019072919832507336
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500}
# Train Accuracy:  0.9999972549434469
# Valid Accuracy:  0.9027692789352388
# Train MSE:  2.262938203809618e-06
# Valid MSE:  0.0019116755631782977
# ------------------------
# Parameters:  {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 1000}
# Train Accuracy:  0.9999972549200752
# Valid Accuracy:  0.9027690974863016
# Train MSE:  2.262957470713397e-06
# Valid MSE:  0.0019116791306875726
# ------------------------
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000}
# Train Accuracy Model:  0.998598245990069
# Test Accuracy Model:  0.1903111648178816
# Train MSE Model:  0.0004697645558886879
# Test MSE Model:  0.30174463182906847
# ------------------------
