# %%
import pandas as pd 
import matplotlib.pyplot as plt

df = pd.read_csv('BCE.csv', sep='\t', index_col='Unnamed: 0')
df.head()
print(len(df))
# Out:
# 3187

# %%
change = df['Close'].diff()
change.dropna(inplace=True)
change.head()
# Out:
# 1   -113.0
# 2    -67.0
# 3      0.0
# 4    -23.0
# 5   -135.0
# Name: Close, dtype: float64

# %%
change_up = change.copy()
change_down = change.copy()

# %%
change_up[change_up<0] = 0
change_down[change_down>0] = 0
change.equals(change_up+change_down)
avg_up = change_up.rolling(14).mean()
avg_down = change_down.rolling(14).mean().abs()
rsi = 100 * avg_up / (avg_up + avg_down)

rsi.head(20)
print(type(rsi))
print(len(rsi))
# Out:
# <class 'pandas.core.series.Series'>
# 3186

# %%
plt.style.use('fivethirtyeight')

plt.rcParams['figure.figsize'] = (20, 20)

# %%
ax1 = plt.subplot2grid((10,1), (0,0), rowspan = 4, colspan = 1)
ax2 = plt.subplot2grid((10,1), (5,0), rowspan = 4, colspan = 1)


ax1.plot(df['Close'], linewidth=2)
ax1.set_title('Close Price')

ax2.set_title('Relative Strength Index')
ax2.plot(rsi, color='orange', linewidth=1)

ax2.axhline(30, linestyle='--', linewidth=1.5, color='green')
ax2.axhline(70, linestyle='--', linewidth=1.5, color='red')

# %%
df['TraingDate'] = pd.to_datetime(df['TradingDate'], format='%Y/%m/%d')
new_dataset = df[['TradingDate','Volume']]
new_dataset.index = new_dataset['TradingDate']

# %%
df.head()
# Out:
#      Open    High     Low   Close  Volume TradingDate Code TraingDate
# 0  5417.0  5869.0  5417.0  5417.0  267360  2010-06-28  BCE 2010-06-28
# 1  5169.0  5417.0  5169.0  5304.0  218580  2010-06-29  BCE 2010-06-29
# 2  5079.0  5530.0  5079.0  5237.0   50850  2010-06-30  BCE 2010-06-30
# 3  5304.0  5304.0  5191.0  5237.0   42290  2010-07-01  BCE 2010-07-01
# 4  5462.0  5462.0  5191.0  5214.0   75300  2010-07-02  BCE 2010-07-02

# %%
count = int(np.ceil(len(df) * 0.1))
signals = pd.DataFrame(index=df.index)
signals['signal'] = 0.0
signals['trend'] = df['Close']
signals['RollingMax'] = (signals.trend.shift(1).rolling(count).max())
signals['RollingMin'] = (signals.trend.shift(1).rolling(count).min())
signals.loc[signals['RollingMax'] < signals.trend, 'signal'] = -1
signals.loc[signals['RollingMin'] > signals.trend, 'signal'] = 1
signals
# Out:
#       signal   trend  RollingMax  RollingMin
# 0        0.0  5417.0         NaN         NaN
# 1        0.0  5304.0         NaN         NaN
# 2        0.0  5237.0         NaN         NaN
# 3        0.0  5237.0         NaN         NaN
# 4        0.0  5214.0         NaN         NaN
# ...      ...     ...         ...         ...
# 3182     0.0  5550.0     20900.0      4830.0
# 3183     0.0  5550.0     20900.0      4830.0
# 3184     0.0  5490.0     20900.0      4830.0
# 3185     0.0  5500.0     20900.0      4830.0
# 3186     0.0  5450.0     20900.0      4830.0
#
# [3187 rows x 4 columns]

# %%
def buy_stock(
    real_movement,
    signal,
    initial_money = 10000,
    max_buy = 1,
    max_sell = 1,
):
    """
    real_movement = actual movement in the real world
    delay = how much interval you want to delay to change our decision from buy to sell, vice versa
    initial_state = 1 is buy, 0 is sell
    initial_money = 1000, ignore what kind of currency
    max_buy = max quantity for share to buy
    max_sell = max quantity for share to sell
    """
    starting_money = initial_money
    states_sell = []
    states_buy = []
    current_inventory = 0

    def buy(i, initial_money, current_inventory):
        shares = initial_money // real_movement[i]
        if shares < 1:
            print(
                'day %d: total balances %f, not enough money to buy a unit price %f'
                % (i, initial_money, real_movement[i])
            )
        else:
            if shares > max_buy:
                buy_units = max_buy
            else:
                buy_units = shares
            initial_money -= buy_units * real_movement[i]
            current_inventory += buy_units
            print(
                'day %d: buy %d units at price %f, total balance %f'
                % (i, buy_units, buy_units * real_movement[i], initial_money)
            )
            states_buy.append(0)
        return initial_money, current_inventory

    for i in range(real_movement.shape[0] - int(0.025 * len(df))):
        state = signal[i]
        if state == 1:
            initial_money, current_inventory = buy(
                i, initial_money, current_inventory
            )
            states_buy.append(i)
        elif state == -1:
            if current_inventory == 0:
                    print('day %d: cannot sell anything, inventory 0' % (i))
            else:
                if current_inventory > max_sell:
                    sell_units = max_sell
                else:
                    sell_units = current_inventory
                current_inventory -= sell_units
                total_sell = sell_units * real_movement[i]
                initial_money += total_sell
                try:
                    invest = (
                        (real_movement[i] - real_movement[states_buy[-1]])
                        / real_movement[states_buy[-1]]
                    ) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                    % (i, sell_units, total_sell, invest, initial_money)
                )
            states_sell.append(i)
            
    invest = ((initial_money - starting_money) / starting_money) * 100
    total_gains = initial_money - starting_money
    return states_buy, states_sell, total_gains, invest

# %%
states_buy, states_sell, total_gains, invest = buy_stock(df.Close, signals['signal'])
# Out:
# day 374: buy 1 units at price 1881.000000, total balance 8119.000000
# day 461, sell 1 units at price 3628.000000, investment 92.876130 %, total balance 11747.000000,
# day 462: cannot sell anything, inventory 0
# day 465: cannot sell anything, inventory 0
# day 881: cannot sell anything, inventory 0
# day 882: cannot sell anything, inventory 0
# day 883: cannot sell anything, inventory 0
# day 885: cannot sell anything, inventory 0
# day 887: cannot sell anything, inventory 0
# day 888: cannot sell anything, inventory 0
# day 890: cannot sell anything, inventory 0
# day 891: cannot sell anything, inventory 0
# day 892: cannot sell anything, inventory 0
# day 893: cannot sell anything, inventory 0
# day 897: cannot sell anything, inventory 0
# day 898: cannot sell anything, inventory 0
# day 899: cannot sell anything, inventory 0
# day 901: cannot sell anything, inventory 0
# day 903: cannot sell anything, inventory 0
# day 904: cannot sell anything, inventory 0
# day 907: cannot sell anything, inventory 0
# day 908: cannot sell anything, inventory 0
# day 919: cannot sell anything, inventory 0
# day 920: cannot sell anything, inventory 0
# day 921: cannot sell anything, inventory 0
# day 931: cannot sell anything, inventory 0
# day 932: cannot sell anything, inventory 0
# day 1203: buy 1 units at price 3816.000000, total balance 7931.000000
# day 1205: buy 1 units at price 3639.000000, total balance 4292.000000
# day 1279: buy 1 units at price 3523.000000, total balance 769.000000
# day 1280: total balances 769.000000, not enough money to buy a unit price 3378.000000
# day 1282: total balances 769.000000, not enough money to buy a unit price 3282.000000
# day 1283: total balances 769.000000, not enough money to buy a unit price 3137.000000
# day 1284: total balances 769.000000, not enough money to buy a unit price 3041.000000
# day 1583: total balances 769.000000, not enough money to buy a unit price 3027.000000
# day 1584: total balances 769.000000, not enough money to buy a unit price 2979.000000
# day 1939, sell 1 units at price 3881.000000, investment 30.278617 %, total balance 4650.000000,
# day 1940, sell 1 units at price 3954.000000, investment 32.729104 %, total balance 8604.000000,
# day 1941, sell 1 units at price 3978.000000, investment 33.534743 %, total balance 12582.000000,
# day 1942: cannot sell anything, inventory 0
# day 1943: cannot sell anything, inventory 0
# day 1944: cannot sell anything, inventory 0
# day 1945: cannot sell anything, inventory 0
# day 1946: cannot sell anything, inventory 0
# day 2140: cannot sell anything, inventory 0
# day 2152: cannot sell anything, inventory 0
# day 2153: cannot sell anything, inventory 0
# day 2154: cannot sell anything, inventory 0
# day 2155: cannot sell anything, inventory 0
# day 2164: cannot sell anything, inventory 0
# day 2165: cannot sell anything, inventory 0
# day 2166: cannot sell anything, inventory 0
# day 2170: cannot sell anything, inventory 0
# day 2174: cannot sell anything, inventory 0
# day 2175: cannot sell anything, inventory 0
# day 2200: cannot sell anything, inventory 0
# day 2222: cannot sell anything, inventory 0
# day 2223: cannot sell anything, inventory 0
# day 2272: cannot sell anything, inventory 0
# day 2279: cannot sell anything, inventory 0
# day 2282: cannot sell anything, inventory 0
# day 2283: cannot sell anything, inventory 0
# day 2289: cannot sell anything, inventory 0
# day 2450: cannot sell anything, inventory 0
# day 2451: cannot sell anything, inventory 0
# day 2459: cannot sell anything, inventory 0
# day 2482: cannot sell anything, inventory 0
# day 2483: cannot sell anything, inventory 0
# day 2511: cannot sell anything, inventory 0
# day 2530: cannot sell anything, inventory 0
# day 2531: cannot sell anything, inventory 0
# day 2538: cannot sell anything, inventory 0
# day 2540: cannot sell anything, inventory 0
# day 2541: cannot sell anything, inventory 0
# day 2598: cannot sell anything, inventory 0
# day 2611: cannot sell anything, inventory 0
# day 2612: cannot sell anything, inventory 0
# day 2616: cannot sell anything, inventory 0
# day 2617: cannot sell anything, inventory 0
# day 2618: cannot sell anything, inventory 0
# day 2620: cannot sell anything, inventory 0
# day 2621: cannot sell anything, inventory 0
# day 2622: cannot sell anything, inventory 0
# day 2623: cannot sell anything, inventory 0
# day 2624: cannot sell anything, inventory 0
# day 2625: cannot sell anything, inventory 0
# day 2626: cannot sell anything, inventory 0
# day 2635: cannot sell anything, inventory 0
# day 2666: cannot sell anything, inventory 0
# day 2668: cannot sell anything, inventory 0
# day 2792: cannot sell anything, inventory 0
# day 2803: cannot sell anything, inventory 0
# day 2804: cannot sell anything, inventory 0
# day 2805: cannot sell anything, inventory 0
# day 2816: cannot sell anything, inventory 0
# day 2820: cannot sell anything, inventory 0
# day 2823: cannot sell anything, inventory 0
# day 2825: cannot sell anything, inventory 0
# day 2826: cannot sell anything, inventory 0
# day 2827: cannot sell anything, inventory 0
# day 2828: cannot sell anything, inventory 0
# day 2829: cannot sell anything, inventory 0
# day 2830: cannot sell anything, inventory 0
# day 2831: cannot sell anything, inventory 0
# day 2834: cannot sell anything, inventory 0
# day 2835: cannot sell anything, inventory 0
# day 2985: buy 1 units at price 9860.000000, total balance 2722.000000
# day 2986: total balances 2722.000000, not enough money to buy a unit price 9830.000000
# day 2987: total balances 2722.000000, not enough money to buy a unit price 9390.000000
# day 2988: total balances 2722.000000, not enough money to buy a unit price 9380.000000
# day 2989: total balances 2722.000000, not enough money to buy a unit price 8860.000000
# day 2990: total balances 2722.000000, not enough money to buy a unit price 8240.000000
# day 2991: total balances 2722.000000, not enough money to buy a unit price 8010.000000
# day 3066: total balances 2722.000000, not enough money to buy a unit price 7910.000000
# day 3067: total balances 2722.000000, not enough money to buy a unit price 7360.000000
# day 3068: total balances 2722.000000, not enough money to buy a unit price 7100.000000
# day 3069: total balances 2722.000000, not enough money to buy a unit price 6610.000000
# day 3078: total balances 2722.000000, not enough money to buy a unit price 6230.000000
# day 3079: total balances 2722.000000, not enough money to buy a unit price 6000.000000
# day 3080: total balances 2722.000000, not enough money to buy a unit price 5840.000000
# day 3091: total balances 2722.000000, not enough money to buy a unit price 5630.000000
# day 3092: total balances 2722.000000, not enough money to buy a unit price 5580.000000
# day 3093: total balances 2722.000000, not enough money to buy a unit price 5190.000000
# day 3094: total balances 2722.000000, not enough money to buy a unit price 4830.000000

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
